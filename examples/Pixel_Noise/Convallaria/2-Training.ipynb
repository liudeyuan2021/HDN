# %% [markdown]
# # Training a Hierarchical DivNoising network for Convallaria data which is intrinsically noisy
# This notebook contains an example on how to train a Hierarchical DivNoising Ladder VAE for an intrinsically noisy data. This requires having a noise model (model of the imaging noise) which can be either measured from calibration data or bootstrapped from raw noisy images themselves. If you haven't done so, please first run '1-CreateNoiseModel.ipynb', which will download the data and create a noise model.

# %%
import warnings
warnings.filterwarnings('ignore')
# We import all our dependencies.
import numpy as np
import torch
import sys
sys.path.append('../../../')
from models.lvae import LadderVAE
from lib.gaussianMixtureNoiseModel import GaussianMixtureNoiseModel
from boilerplate import boilerplate
import lib.utils as utils
import training
from tifffile import imread
from matplotlib import pyplot as plt
from tqdm import tqdm

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# ### Specify ```path``` to load training data
# Your data should be stored in the directory indicated by ```path```.

# %%
path="./data/Convallaria_diaphragm/"
observation= imread(path+'20190520_tl_25um_50msec_05pc_488_130EM_Conv.tif')

# %% [markdown]
# # Training Data Preparation

# %% [markdown]
# For training we need to follow some preprocessing steps first which will prepare the data for training purposes.

# %% [markdown]
# We first divide the data into training and validation sets with 85% images allocated to training set  and rest to validation set. Then we augment the training data 8-fold by 90 degree rotations and flips.

# %%
train_data = observation[:int(0.85*observation.shape[0])]
val_data= observation[int(0.85*observation.shape[0]):]
print("Shape of training images:", train_data.shape, "Shape of validation images:", val_data.shape)
train_data = utils.augment_data(train_data) ### Data augmentation disabled for fast training, but can be enabled
# Out:
# Shape of training images: (85, 1024, 1024) Shape of validation images: (15, 1024, 1024)
# Raw image size after augmentation (680, 1024, 1024)

# %%
### We extract overlapping patches of size ```patch_size x patch_size``` from training and validation images.
### Usually 64x64 patches work well for most microscopy datasets
patch_size = 64

# %%
img_width = observation.shape[2]
img_height = observation.shape[1]
num_patches = int(float(img_width*img_height)/float(patch_size**2)*1)
train_images = utils.extract_patches(train_data, patch_size, num_patches)
val_images = utils.extract_patches(val_data, patch_size, num_patches)
val_images = val_images[:1000] # We limit validation patches to 1000 to speed up training but it is not necessary
test_images = val_images[:100]
img_shape = (train_images.shape[1], train_images.shape[2])
print("Shape of training images:", train_images.shape, "Shape of validation images:", val_images.shape)
# Out:
# 100%|██████████| 680/680 [00:01<00:00, 503.12it/s]
# 100%|██████████| 15/15 [00:00<00:00, 508.43it/s]
# Shape of training images: (174080, 64, 64) Shape of validation images: (1000, 64, 64)

# %% [markdown]
# # Configure Hierarchical DivNoising model

# %% [markdown]
# <code>model_name</code> specifies the name of the model with which the weights will be saved and wil be loaded later for prediction.<br>
# <code>directory_path</code> specifies the directory where the model weights and the intermediate denoising and generation results will be saved. <br>
# <code>gaussian_noise_std</code> is only applicable if dataset is synthetically corrupted with Gaussian noise of known std. For real datasets, it should be set to ```None```.<br>
# <code>noiseModel</code> specifies a noise model for training. If noisy data is generated synthetically using Gaussian noise, set it to None. Else set it to the GMM based noise model (.npz file)  generated from '1-CreateNoiseModel.ipynb'.<br>
# <code>batch_size</code> specifies the batch size used for training. The default batch size of $64$ works well for most microscopy datasets.<br>
# <code>virtual_batch</code> specifies the virtual batch size used for training. It divides the <code>batch_size</code> into smaller mini-batches of size <code>virtual_batch</code>. Decrease this if batches do not fit in memory.<br>
# <code>test_batch_size</code> specifies the batch size used for testing every $1000$ training steps. Decrease this if test batches do not fit in memory, it does not have any consequence on training. It is just for intermediate visual debugging.<br>
# <code>lr</code> specifies the learning rate.<br>
# <code>max_epochs</code> specifies the total number of training epochs. Around $150-200$ epochs work well generally.<br>
# <code>steps_per_epoch</code> specifies how many steps to take per epoch of training. Around $400-500$ steps work well for most datasets.<br>
# <code>num_latents</code> specifies the number of stochastic layers. The default setting of $6$ works well for most datasets but quite good results can also be obtained with as less as $4$ layers. However, more stochastic layers may improve performance for some datasets at the cost of increased training time.<br>
# <code>z_dims</code> specifies the number of bottleneck dimensions (latent space dimensions) at each stochastic layer per pixel. The default setting of $32$ works well for most datasets.<br>
# <code>blocks_per_layer</code> specifies how many residual blocks to use per stochastic layer. Usually, setting it to be $4$ or more works well. However, more residual blocks improve performance at the cost of increased training time.<br>
# <code>batchnorm</code> specifies if batch normalization is used or not. Turning it to True is recommended.<br>
# <code>free_bits</code> specifies the threshold below which KL loss is not optimized for. This prevents the [KL-collapse problem](https://arxiv.org/pdf/1511.06349.pdf%3Futm_campaign%3DRevue%2520newsletter%26utm_medium%3DNewsletter%26utm_source%3Drevue). The default setting of $1.0$ works well for most datasets.<br>
#
# **__Note:__** With these settings, training will take approximately $24$ hours on Tesla P100/Titan Xp GPU needing about 6 GB GPU memory. We optimized the code to run on less GPU memory. For faster training, consider increasing ```virtual_batch_size``` but since we have not tested with different settings of ```virtual_batch_size```, we do not yet know how this affects results. To reduce traing time, also consider reducing either ```num_latents``` or ```blocks_per_layer``` to $4$. These settings will bring down the training time to around $12-15$ hours while still giving good results.

# %%
model_name = "convallaria"
directory_path = "./Trained_model/" 

# Data-specific
gaussian_noise_std = None
noise_model_params= np.load("./data/Convallaria_diaphragm/GMMNoiseModel_convallaria_3_2_calibration.npz")
noiseModel = GaussianMixtureNoiseModel(params = noise_model_params, device = device)

# Training-specific
batch_size=64
virtual_batch = 8
lr=3e-4
max_epochs = 500
steps_per_epoch=400
test_batch_size=100

# Model-specific
num_latents = 6
z_dims = [32]*int(num_latents)
blocks_per_layer = 5
batchnorm = True
free_bits = 1.0

# %% [markdown]
# # Train network

# %%
train_loader, val_loader, test_loader, data_mean, data_std = boilerplate._make_datamanager(train_images,val_images,
                                                                                           test_images,batch_size,
                                                                                           test_batch_size)

model = LadderVAE(z_dims=z_dims,blocks_per_layer=blocks_per_layer,data_mean=data_mean,data_std=data_std,noiseModel=noiseModel,
                  device=device,batchnorm=batchnorm,free_bits=free_bits,img_shape=img_shape).cuda()

model.train() # Model set in training mode

training.train_network(model=model,lr=lr,max_epochs=max_epochs,steps_per_epoch=steps_per_epoch,directory_path=directory_path,
                       train_loader=train_loader,val_loader=val_loader,test_loader=test_loader,
                       virtual_batch=virtual_batch,gaussian_noise_std=gaussian_noise_std,
                       model_name=model_name,val_loss_patience=30)
# Out:
# Testing the model at step 0
# Epoch[1/500] Training Loss: 6.905 Reconstruction Loss: 6.620 KL Loss: 0.285
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.437887191772461 Min validation loss: 6.437887191772461
# Time for epoch: 310seconds
# Est remaining time: 1 day, 18:58:10 or 154690 seconds
# ----------------------------------------
# Epoch[2/500] Training Loss: 6.466 Reconstruction Loss: 6.264 KL Loss: 0.202
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.373982906341553 Min validation loss: 6.373982906341553
# Time for epoch: 303seconds
# Est remaining time: 1 day, 17:54:54 or 150894 seconds
# ----------------------------------------
# Testing the model at step 1000
# Epoch[3/500] Training Loss: 6.387 Reconstruction Loss: 6.201 KL Loss: 0.186
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.338604927062988 Min validation loss: 6.338604927062988
# Time for epoch: 303seconds
# Est remaining time: 1 day, 17:49:51 or 150591 seconds
# ----------------------------------------
# Epoch[4/500] Training Loss: 6.350 Reconstruction Loss: 6.171 KL Loss: 0.179
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.302260398864746 Min validation loss: 6.302260398864746
# Time for epoch: 304seconds
# Est remaining time: 1 day, 17:53:04 or 150784 seconds
# ----------------------------------------
# Epoch[5/500] Training Loss: 6.328 Reconstruction Loss: 6.152 KL Loss: 0.176
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.299999237060547 Min validation loss: 6.299999237060547
# Time for epoch: 307seconds
# Est remaining time: 1 day, 18:12:45 or 151965 seconds
# ----------------------------------------
# Testing the model at step 2000
# Epoch[6/500] Training Loss: 6.310 Reconstruction Loss: 6.135 KL Loss: 0.175
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.279787063598633 Min validation loss: 6.279787063598633
# Time for epoch: 305seconds
# Est remaining time: 1 day, 17:51:10 or 150670 seconds
# ----------------------------------------
# Epoch[7/500] Training Loss: 6.293 Reconstruction Loss: 6.119 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.277667999267578 Min validation loss: 6.277667999267578
# Time for epoch: 303seconds
# Est remaining time: 1 day, 17:29:39 or 149379 seconds
# ----------------------------------------
# Testing the model at step 3000
# Epoch[8/500] Training Loss: 6.283 Reconstruction Loss: 6.113 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.2672834396362305 Min validation loss: 6.2672834396362305
# Time for epoch: 304seconds
# Est remaining time: 1 day, 17:32:48 or 149568 seconds
# ----------------------------------------
# Epoch[9/500] Training Loss: 6.275 Reconstruction Loss: 6.107 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.264768600463867 Min validation loss: 6.264768600463867
# Time for epoch: 305seconds
# Est remaining time: 1 day, 17:35:55 or 149755 seconds
# ----------------------------------------
# Epoch[10/500] Training Loss: 6.272 Reconstruction Loss: 6.104 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.260209083557129 Min validation loss: 6.260209083557129
# Time for epoch: 306seconds
# Est remaining time: 1 day, 17:39:00 or 149940 seconds
# ----------------------------------------
# Testing the model at step 4000
# Epoch[11/500] Training Loss: 6.266 Reconstruction Loss: 6.098 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.2587175369262695 Min validation loss: 6.2587175369262695
# Time for epoch: 305seconds
# Est remaining time: 1 day, 17:25:45 or 149145 seconds
# ----------------------------------------
# Epoch[12/500] Training Loss: 6.260 Reconstruction Loss: 6.093 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.259010314941406 Min validation loss: 6.2587175369262695
# Time for epoch: 303seconds
# Est remaining time: 1 day, 17:04:24 or 147864 seconds
# ----------------------------------------
# Testing the model at step 5000
# Epoch[13/500] Training Loss: 6.255 Reconstruction Loss: 6.087 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.25225830078125 Min validation loss: 6.25225830078125
# Time for epoch: 305seconds
# Est remaining time: 1 day, 17:15:35 or 148535 seconds
# ----------------------------------------
# Epoch[14/500] Training Loss: 6.252 Reconstruction Loss: 6.085 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.245806694030762 Min validation loss: 6.245806694030762
# Time for epoch: 306seconds
# Est remaining time: 1 day, 17:18:36 or 148716 seconds
# ----------------------------------------
# Epoch[15/500] Training Loss: 6.251 Reconstruction Loss: 6.084 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.243640899658203 Min validation loss: 6.243640899658203
# Time for epoch: 304seconds
# Est remaining time: 1 day, 16:57:20 or 147440 seconds
# ----------------------------------------
# Testing the model at step 6000
# Epoch[16/500] Training Loss: 6.251 Reconstruction Loss: 6.084 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.257590293884277 Min validation loss: 6.243640899658203
# Time for epoch: 303seconds
# Est remaining time: 1 day, 16:44:12 or 146652 seconds
# ----------------------------------------
# Epoch[17/500] Training Loss: 6.247 Reconstruction Loss: 6.080 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.245412349700928 Min validation loss: 6.243640899658203
# Time for epoch: 305seconds
# Est remaining time: 1 day, 16:55:15 or 147315 seconds
# ----------------------------------------
# Testing the model at step 7000
# Epoch[18/500] Training Loss: 6.246 Reconstruction Loss: 6.079 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.242323875427246 Min validation loss: 6.242323875427246
# Time for epoch: 308seconds
# Est remaining time: 1 day, 17:14:16 or 148456 seconds
# ----------------------------------------
# Epoch[19/500] Training Loss: 6.241 Reconstruction Loss: 6.075 KL Loss: 0.166
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.238348007202148 Min validation loss: 6.238348007202148
# Time for epoch: 479seconds
# Est remaining time: 2 days, 15:59:59 or 230399 seconds
# ----------------------------------------
# Epoch[20/500] Training Loss: 6.241 Reconstruction Loss: 6.076 KL Loss: 0.166
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.239691734313965 Min validation loss: 6.238348007202148
# Time for epoch: 303seconds
# Est remaining time: 1 day, 16:24:00 or 145440 seconds
# ----------------------------------------
# Testing the model at step 8000
# Epoch[21/500] Training Loss: 6.242 Reconstruction Loss: 6.076 KL Loss: 0.166
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.241055488586426 Min validation loss: 6.238348007202148
# Time for epoch: 305seconds
# Est remaining time: 1 day, 16:34:55 or 146095 seconds
# ----------------------------------------
# Epoch[22/500] Training Loss: 6.239 Reconstruction Loss: 6.073 KL Loss: 0.165
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.241194248199463 Min validation loss: 6.238348007202148
# Time for epoch: 306seconds
# Est remaining time: 1 day, 16:37:48 or 146268 seconds
# ----------------------------------------
# Testing the model at step 9000
# Epoch[23/500] Training Loss: 6.236 Reconstruction Loss: 6.071 KL Loss: 0.165
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.240645408630371 Min validation loss: 6.238348007202148
# Time for epoch: 305seconds
# Est remaining time: 1 day, 16:24:45 or 145485 seconds
# ----------------------------------------
# Epoch[24/500] Training Loss: 6.236 Reconstruction Loss: 6.072 KL Loss: 0.165
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.233506679534912 Min validation loss: 6.233506679534912
# Time for epoch: 303seconds
# Est remaining time: 1 day, 16:03:48 or 144228 seconds
# ----------------------------------------
# Epoch[25/500] Training Loss: 6.234 Reconstruction Loss: 6.070 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.236050605773926 Min validation loss: 6.233506679534912
# Time for epoch: 304seconds
# Est remaining time: 1 day, 16:06:40 or 144400 seconds
# ----------------------------------------
# Testing the model at step 10000
# Epoch[26/500] Training Loss: 6.235 Reconstruction Loss: 6.070 KL Loss: 0.165
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.231494903564453 Min validation loss: 6.231494903564453
# Time for epoch: 306seconds
# Est remaining time: 1 day, 16:17:24 or 145044 seconds
# ----------------------------------------
# Epoch[27/500] Training Loss: 6.231 Reconstruction Loss: 6.067 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.235586166381836 Min validation loss: 6.231494903564453
# Time for epoch: 305seconds
# Est remaining time: 1 day, 16:04:25 or 144265 seconds
# ----------------------------------------
# Testing the model at step 11000
# Epoch[28/500] Training Loss: 6.230 Reconstruction Loss: 6.066 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.2421979904174805 Min validation loss: 6.231494903564453
# Time for epoch: 303seconds
# Est remaining time: 1 day, 15:43:36 or 143016 seconds
# ----------------------------------------
# Epoch[29/500] Training Loss: 6.231 Reconstruction Loss: 6.067 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.23197078704834 Min validation loss: 6.231494903564453
# Time for epoch: 304seconds
# Est remaining time: 1 day, 15:46:24 or 143184 seconds
# ----------------------------------------
# Epoch[30/500] Training Loss: 6.230 Reconstruction Loss: 6.066 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.232712745666504 Min validation loss: 6.231494903564453
# Time for epoch: 305seconds
# Est remaining time: 1 day, 15:49:10 or 143350 seconds
# ----------------------------------------
# Testing the model at step 12000
# Epoch[31/500] Training Loss: 6.232 Reconstruction Loss: 6.068 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 5 Validation Loss: 6.232809543609619 Min validation loss: 6.231494903564453
# Time for epoch: 305seconds
# Est remaining time: 1 day, 15:44:05 or 143045 seconds
# ----------------------------------------
# Epoch[32/500] Training Loss: 6.233 Reconstruction Loss: 6.068 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 6 Validation Loss: 6.231873512268066 Min validation loss: 6.231494903564453
# Time for epoch: 304seconds
# Est remaining time: 1 day, 15:31:12 or 142272 seconds
# ----------------------------------------
# Testing the model at step 13000
# Epoch[33/500] Training Loss: 6.228 Reconstruction Loss: 6.065 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.230913162231445 Min validation loss: 6.230913162231445
# Time for epoch: 303seconds
# Est remaining time: 1 day, 15:18:21 or 141501 seconds
# ----------------------------------------
# Epoch[34/500] Training Loss: 6.225 Reconstruction Loss: 6.061 KL Loss: 0.163
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.229211330413818 Min validation loss: 6.229211330413818
# Time for epoch: 303seconds
# Est remaining time: 1 day, 15:13:18 or 141198 seconds
# ----------------------------------------
# Epoch[35/500] Training Loss: 6.227 Reconstruction Loss: 6.063 KL Loss: 0.163
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.2264580726623535 Min validation loss: 6.2264580726623535
# Time for epoch: 305seconds
# Est remaining time: 1 day, 15:23:45 or 141825 seconds
# ----------------------------------------
# Testing the model at step 14000
# Epoch[36/500] Training Loss: 6.226 Reconstruction Loss: 6.062 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.226749897003174 Min validation loss: 6.2264580726623535
# Time for epoch: 306seconds
# Est remaining time: 1 day, 15:26:24 or 141984 seconds
# ----------------------------------------
# Epoch[37/500] Training Loss: 6.224 Reconstruction Loss: 6.060 KL Loss: 0.164
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.22536563873291 Min validation loss: 6.22536563873291
# Time for epoch: 305seconds
# Est remaining time: 1 day, 15:13:35 or 141215 seconds
# ----------------------------------------
# Testing the model at step 15000
# Epoch[38/500] Training Loss: 6.223 Reconstruction Loss: 6.057 KL Loss: 0.166
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.231267929077148 Min validation loss: 6.22536563873291
# Time for epoch: 304seconds
# Est remaining time: 1 day, 15:00:48 or 140448 seconds
# ----------------------------------------
# Epoch[39/500] Training Loss: 6.222 Reconstruction Loss: 6.055 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.223612308502197 Min validation loss: 6.223612308502197
# Time for epoch: 304seconds
# Est remaining time: 1 day, 14:55:44 or 140144 seconds
# ----------------------------------------
# Epoch[40/500] Training Loss: 6.221 Reconstruction Loss: 6.054 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.22374153137207 Min validation loss: 6.223612308502197
# Time for epoch: 306seconds
# Est remaining time: 1 day, 15:06:00 or 140760 seconds
# ----------------------------------------
# Testing the model at step 16000
# Epoch[41/500] Training Loss: 6.219 Reconstruction Loss: 6.051 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.224236011505127 Min validation loss: 6.223612308502197
# Time for epoch: 305seconds
# Est remaining time: 1 day, 14:53:15 or 139995 seconds
# ----------------------------------------
# Epoch[42/500] Training Loss: 6.220 Reconstruction Loss: 6.053 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.220746994018555 Min validation loss: 6.220746994018555
# Time for epoch: 303seconds
# Est remaining time: 1 day, 14:32:54 or 138774 seconds
# ----------------------------------------
# Testing the model at step 17000
# Epoch[43/500] Training Loss: 6.222 Reconstruction Loss: 6.054 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.219751358032227 Min validation loss: 6.219751358032227
# Time for epoch: 304seconds
# Est remaining time: 1 day, 14:35:28 or 138928 seconds
# ----------------------------------------
# Epoch[44/500] Training Loss: 6.215 Reconstruction Loss: 6.048 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.220354080200195 Min validation loss: 6.219751358032227
# Time for epoch: 306seconds
# Est remaining time: 1 day, 14:45:36 or 139536 seconds
# ----------------------------------------
# Epoch[45/500] Training Loss: 6.218 Reconstruction Loss: 6.050 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.219047546386719 Min validation loss: 6.219047546386719
# Time for epoch: 306seconds
# Est remaining time: 1 day, 14:40:30 or 139230 seconds
# ----------------------------------------
# Testing the model at step 18000
# Epoch[46/500] Training Loss: 6.219 Reconstruction Loss: 6.052 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.219857215881348 Min validation loss: 6.219047546386719
# Time for epoch: 304seconds
# Est remaining time: 1 day, 14:20:16 or 138016 seconds
# ----------------------------------------
# Epoch[47/500] Training Loss: 6.218 Reconstruction Loss: 6.050 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.218105316162109 Min validation loss: 6.218105316162109
# Time for epoch: 303seconds
# Est remaining time: 1 day, 14:07:39 or 137259 seconds
# ----------------------------------------
# Testing the model at step 19000
# Epoch[48/500] Training Loss: 6.219 Reconstruction Loss: 6.052 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.218837738037109 Min validation loss: 6.218105316162109
# Time for epoch: 306seconds
# Est remaining time: 1 day, 14:25:12 or 138312 seconds
# ----------------------------------------
# Epoch[49/500] Training Loss: 6.216 Reconstruction Loss: 6.048 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.218601703643799 Min validation loss: 6.218105316162109
# Time for epoch: 306seconds
# Est remaining time: 1 day, 14:20:06 or 138006 seconds
# ----------------------------------------
# Epoch[50/500] Training Loss: 6.219 Reconstruction Loss: 6.051 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.220296859741211 Min validation loss: 6.218105316162109
# Time for epoch: 304seconds
# Est remaining time: 1 day, 14:00:00 or 136800 seconds
# ----------------------------------------
# Testing the model at step 20000
# Epoch[51/500] Training Loss: 6.215 Reconstruction Loss: 6.047 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.219111442565918 Min validation loss: 6.218105316162109
# Time for epoch: 303seconds
# Est remaining time: 1 day, 13:47:27 or 136047 seconds
# ----------------------------------------
# Epoch[52/500] Training Loss: 6.214 Reconstruction Loss: 6.047 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.216388702392578 Min validation loss: 6.216388702392578
# Time for epoch: 303seconds
# Est remaining time: 1 day, 13:42:24 or 135744 seconds
# ----------------------------------------
# Testing the model at step 21000
# Epoch[53/500] Training Loss: 6.214 Reconstruction Loss: 6.047 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.220322132110596 Min validation loss: 6.216388702392578
# Time for epoch: 305seconds
# Est remaining time: 1 day, 13:52:15 or 136335 seconds
# ----------------------------------------
# Epoch[54/500] Training Loss: 6.215 Reconstruction Loss: 6.047 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.21546745300293 Min validation loss: 6.21546745300293
# Time for epoch: 305seconds
# Est remaining time: 1 day, 13:47:10 or 136030 seconds
# ----------------------------------------
# Epoch[55/500] Training Loss: 6.214 Reconstruction Loss: 6.046 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.230809211730957 Min validation loss: 6.21546745300293
# Time for epoch: 305seconds
# Est remaining time: 1 day, 13:42:05 or 135725 seconds
# ----------------------------------------
# Testing the model at step 22000
# Epoch[56/500] Training Loss: 6.213 Reconstruction Loss: 6.046 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.217222213745117 Min validation loss: 6.21546745300293
# Time for epoch: 303seconds
# Est remaining time: 1 day, 13:22:12 or 134532 seconds
# ----------------------------------------
# Epoch[57/500] Training Loss: 6.212 Reconstruction Loss: 6.045 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.2169904708862305 Min validation loss: 6.21546745300293
# Time for epoch: 303seconds
# Est remaining time: 1 day, 13:17:09 or 134229 seconds
# ----------------------------------------
# Testing the model at step 23000
# Epoch[58/500] Training Loss: 6.215 Reconstruction Loss: 6.047 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.216618537902832 Min validation loss: 6.21546745300293
# Time for epoch: 305seconds
# Est remaining time: 1 day, 13:26:50 or 134810 seconds
# ----------------------------------------
# Epoch[59/500] Training Loss: 6.211 Reconstruction Loss: 6.044 KL Loss: 0.167
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 5 Validation Loss: 6.2177605628967285 Min validation loss: 6.21546745300293
# Time for epoch: 306seconds
# Est remaining time: 1 day, 13:29:06 or 134946 seconds
# ----------------------------------------
# Epoch[60/500] Training Loss: 6.214 Reconstruction Loss: 6.046 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 6 Validation Loss: 6.216884613037109 Min validation loss: 6.21546745300293
# Time for epoch: 304seconds
# Est remaining time: 1 day, 13:09:20 or 133760 seconds
# ----------------------------------------
# Testing the model at step 24000
# Epoch[61/500] Training Loss: 6.214 Reconstruction Loss: 6.046 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.212336540222168 Min validation loss: 6.212336540222168
# Time for epoch: 303seconds
# Est remaining time: 1 day, 12:56:57 or 133017 seconds
# ----------------------------------------
# Epoch[62/500] Training Loss: 6.213 Reconstruction Loss: 6.045 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.21504545211792 Min validation loss: 6.212336540222168
# Time for epoch: 304seconds
# Est remaining time: 1 day, 12:59:12 or 133152 seconds
# ----------------------------------------
# Testing the model at step 25000
# Epoch[63/500] Training Loss: 6.215 Reconstruction Loss: 6.047 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.214974880218506 Min validation loss: 6.212336540222168
# Time for epoch: 306seconds
# Est remaining time: 1 day, 13:08:42 or 133722 seconds
# ----------------------------------------
# Epoch[64/500] Training Loss: 6.210 Reconstruction Loss: 6.042 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.215781211853027 Min validation loss: 6.212336540222168
# Time for epoch: 305seconds
# Est remaining time: 1 day, 12:56:20 or 132980 seconds
# ----------------------------------------
# Epoch[65/500] Training Loss: 6.211 Reconstruction Loss: 6.043 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.216584205627441 Min validation loss: 6.212336540222168
# Time for epoch: 304seconds
# Est remaining time: 1 day, 12:44:00 or 132240 seconds
# ----------------------------------------
# Testing the model at step 26000
# Epoch[66/500] Training Loss: 6.213 Reconstruction Loss: 6.044 KL Loss: 0.168
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 5 Validation Loss: 6.214423179626465 Min validation loss: 6.212336540222168
# Time for epoch: 304seconds
# Est remaining time: 1 day, 12:38:56 or 131936 seconds
# ----------------------------------------
# Epoch[67/500] Training Loss: 6.216 Reconstruction Loss: 6.047 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 6 Validation Loss: 6.214786052703857 Min validation loss: 6.212336540222168
# Time for epoch: 305seconds
# Est remaining time: 1 day, 12:41:05 or 132065 seconds
# ----------------------------------------
# Testing the model at step 27000
# Epoch[68/500] Training Loss: 6.213 Reconstruction Loss: 6.044 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 7 Validation Loss: 6.219709396362305 Min validation loss: 6.212336540222168
# Time for epoch: 305seconds
# Est remaining time: 1 day, 12:36:00 or 131760 seconds
# ----------------------------------------
# Epoch[69/500] Training Loss: 6.213 Reconstruction Loss: 6.044 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 8 Validation Loss: 6.216729640960693 Min validation loss: 6.212336540222168
# Time for epoch: 303seconds
# Est remaining time: 1 day, 12:16:33 or 130593 seconds
# ----------------------------------------
# Epoch[70/500] Training Loss: 6.212 Reconstruction Loss: 6.043 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 9 Validation Loss: 6.2143940925598145 Min validation loss: 6.212336540222168
# Time for epoch: 304seconds
# Est remaining time: 1 day, 12:18:40 or 130720 seconds
# ----------------------------------------
# Testing the model at step 28000
# Epoch[71/500] Training Loss: 6.208 Reconstruction Loss: 6.039 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 10 Validation Loss: 6.214560508728027 Min validation loss: 6.212336540222168
# Time for epoch: 306seconds
# Est remaining time: 1 day, 12:27:54 or 131274 seconds
# ----------------------------------------
# Epoch[72/500] Training Loss: 6.212 Reconstruction Loss: 6.043 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Epoch 00072: reducing learning rate of group 0 to 1.5000e-04.
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.212181568145752 Min validation loss: 6.212181568145752
# Time for epoch: 305seconds
# Est remaining time: 1 day, 12:15:40 or 130540 seconds
# ----------------------------------------
# Testing the model at step 29000
# Epoch[73/500] Training Loss: 6.210 Reconstruction Loss: 6.041 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.2146172523498535 Min validation loss: 6.212181568145752
# Time for epoch: 304seconds
# Est remaining time: 1 day, 12:03:28 or 129808 seconds
# ----------------------------------------
# Epoch[74/500] Training Loss: 6.212 Reconstruction Loss: 6.043 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.216501712799072 Min validation loss: 6.212181568145752
# Time for epoch: 303seconds
# Est remaining time: 1 day, 11:51:18 or 129078 seconds
# ----------------------------------------
# Epoch[75/500] Training Loss: 6.211 Reconstruction Loss: 6.042 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.219064712524414 Min validation loss: 6.212181568145752
# Time for epoch: 304seconds
# Est remaining time: 1 day, 11:53:20 or 129200 seconds
# ----------------------------------------
# Testing the model at step 30000
# Epoch[76/500] Training Loss: 6.211 Reconstruction Loss: 6.041 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.211811065673828 Min validation loss: 6.211811065673828
# Time for epoch: 306seconds
# Est remaining time: 1 day, 12:02:24 or 129744 seconds
# ----------------------------------------
# Epoch[77/500] Training Loss: 6.209 Reconstruction Loss: 6.040 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.213193893432617 Min validation loss: 6.211811065673828
# Time for epoch: 305seconds
# Est remaining time: 1 day, 11:50:15 or 129015 seconds
# ----------------------------------------
# Testing the model at step 31000
# Epoch[78/500] Training Loss: 6.209 Reconstruction Loss: 6.040 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.211109161376953 Min validation loss: 6.211109161376953
# Time for epoch: 303seconds
# Est remaining time: 1 day, 11:31:06 or 127866 seconds
# ----------------------------------------
# Epoch[79/500] Training Loss: 6.208 Reconstruction Loss: 6.039 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.2171759605407715 Min validation loss: 6.211109161376953
# Time for epoch: 303seconds
# Est remaining time: 1 day, 11:26:03 or 127563 seconds
# ----------------------------------------
# Epoch[80/500] Training Loss: 6.210 Reconstruction Loss: 6.041 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.212610244750977 Min validation loss: 6.211109161376953
# Time for epoch: 304seconds
# Est remaining time: 1 day, 11:28:00 or 127680 seconds
# ----------------------------------------
# Testing the model at step 32000
# Epoch[81/500] Training Loss: 6.207 Reconstruction Loss: 6.038 KL Loss: 0.169
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.212428092956543 Min validation loss: 6.211109161376953
# Time for epoch: 306seconds
# Est remaining time: 1 day, 11:36:54 or 128214 seconds
# ----------------------------------------
# Epoch[82/500] Training Loss: 6.210 Reconstruction Loss: 6.040 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.209818363189697 Min validation loss: 6.209818363189697
# Time for epoch: 305seconds
# Est remaining time: 1 day, 11:24:50 or 127490 seconds
# ----------------------------------------
# Testing the model at step 33000
# Epoch[83/500] Training Loss: 6.210 Reconstruction Loss: 6.041 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.211946487426758 Min validation loss: 6.209818363189697
# Time for epoch: 305seconds
# Est remaining time: 1 day, 11:19:45 or 127185 seconds
# ----------------------------------------
# Epoch[84/500] Training Loss: 6.210 Reconstruction Loss: 6.040 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.212828159332275 Min validation loss: 6.209818363189697
# Time for epoch: 303seconds
# Est remaining time: 1 day, 11:00:48 or 126048 seconds
# ----------------------------------------
# Epoch[85/500] Training Loss: 6.209 Reconstruction Loss: 6.039 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.213764190673828 Min validation loss: 6.209818363189697
# Time for epoch: 303seconds
# Est remaining time: 1 day, 10:55:45 or 125745 seconds
# ----------------------------------------
# Testing the model at step 34000
# Epoch[86/500] Training Loss: 6.207 Reconstruction Loss: 6.037 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.214821815490723 Min validation loss: 6.209818363189697
# Time for epoch: 306seconds
# Est remaining time: 1 day, 11:11:24 or 126684 seconds
# ----------------------------------------
# Epoch[87/500] Training Loss: 6.207 Reconstruction Loss: 6.037 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 5 Validation Loss: 6.212001800537109 Min validation loss: 6.209818363189697
# Time for epoch: 304seconds
# Est remaining time: 1 day, 10:52:32 or 125552 seconds
# ----------------------------------------
# Testing the model at step 35000
# Epoch[88/500] Training Loss: 6.212 Reconstruction Loss: 6.041 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 6 Validation Loss: 6.2123942375183105 Min validation loss: 6.209818363189697
# Time for epoch: 303seconds
# Est remaining time: 1 day, 10:40:36 or 124836 seconds
# ----------------------------------------
# Epoch[89/500] Training Loss: 6.208 Reconstruction Loss: 6.037 KL Loss: 0.170
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 7 Validation Loss: 6.210826873779297 Min validation loss: 6.209818363189697
# Time for epoch: 304seconds
# Est remaining time: 1 day, 10:42:24 or 124944 seconds
# ----------------------------------------
# Epoch[90/500] Training Loss: 6.209 Reconstruction Loss: 6.038 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 8 Validation Loss: 6.212862491607666 Min validation loss: 6.209818363189697
# Time for epoch: 305seconds
# Est remaining time: 1 day, 10:44:10 or 125050 seconds
# ----------------------------------------
# Testing the model at step 36000
# Epoch[91/500] Training Loss: 6.208 Reconstruction Loss: 6.037 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 9 Validation Loss: 6.213479042053223 Min validation loss: 6.209818363189697
# Time for epoch: 305seconds
# Est remaining time: 1 day, 10:39:05 or 124745 seconds
# ----------------------------------------
# Epoch[92/500] Training Loss: 6.205 Reconstruction Loss: 6.034 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 10 Validation Loss: 6.212800025939941 Min validation loss: 6.209818363189697
# Time for epoch: 303seconds
# Est remaining time: 1 day, 10:20:24 or 123624 seconds
# ----------------------------------------
# Testing the model at step 37000
# Epoch[93/500] Training Loss: 6.206 Reconstruction Loss: 6.035 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# Epoch 00093: reducing learning rate of group 0 to 7.5000e-05.
# Patience: 11 Validation Loss: 6.211275100708008 Min validation loss: 6.209818363189697
# Time for epoch: 303seconds
# Est remaining time: 1 day, 10:15:21 or 123321 seconds
# ----------------------------------------
# Epoch[94/500] Training Loss: 6.205 Reconstruction Loss: 6.034 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 12 Validation Loss: 6.210212707519531 Min validation loss: 6.209818363189697
# Time for epoch: 306seconds
# Est remaining time: 1 day, 10:30:36 or 124236 seconds
# ----------------------------------------
# Epoch[95/500] Training Loss: 6.207 Reconstruction Loss: 6.036 KL Loss: 0.171
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.208414554595947 Min validation loss: 6.208414554595947
# Time for epoch: 305seconds
# Est remaining time: 1 day, 10:18:45 or 123525 seconds
# ----------------------------------------
# Testing the model at step 38000
# Epoch[96/500] Training Loss: 6.208 Reconstruction Loss: 6.036 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.211057186126709 Min validation loss: 6.208414554595947
# Time for epoch: 303seconds
# Est remaining time: 1 day, 10:00:12 or 122412 seconds
# ----------------------------------------
# Epoch[97/500] Training Loss: 6.206 Reconstruction Loss: 6.034 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.208523273468018 Min validation loss: 6.208414554595947
# Time for epoch: 303seconds
# Est remaining time: 1 day, 9:55:09 or 122109 seconds
# ----------------------------------------
# Testing the model at step 39000
# Epoch[98/500] Training Loss: 6.204 Reconstruction Loss: 6.033 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.208730697631836 Min validation loss: 6.208414554595947
# Time for epoch: 306seconds
# Est remaining time: 1 day, 10:10:12 or 123012 seconds
# ----------------------------------------
# Epoch[99/500] Training Loss: 6.207 Reconstruction Loss: 6.035 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.212045669555664 Min validation loss: 6.208414554595947
# Time for epoch: 306seconds
# Est remaining time: 1 day, 10:05:06 or 122706 seconds
# ----------------------------------------
# Epoch[100/500] Training Loss: 6.206 Reconstruction Loss: 6.034 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 5 Validation Loss: 6.208799362182617 Min validation loss: 6.208414554595947
# Time for epoch: 305seconds
# Est remaining time: 1 day, 9:53:20 or 122000 seconds
# ----------------------------------------
# Testing the model at step 40000
# Epoch[101/500] Training Loss: 6.203 Reconstruction Loss: 6.031 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 6 Validation Loss: 6.209474563598633 Min validation loss: 6.208414554595947
# Time for epoch: 303seconds
# Est remaining time: 1 day, 9:34:57 or 120897 seconds
# ----------------------------------------
# Epoch[102/500] Training Loss: 6.211 Reconstruction Loss: 6.038 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 7 Validation Loss: 6.210002899169922 Min validation loss: 6.208414554595947
# Time for epoch: 303seconds
# Est remaining time: 1 day, 9:29:54 or 120594 seconds
# ----------------------------------------
# Testing the model at step 41000
# Epoch[103/500] Training Loss: 6.206 Reconstruction Loss: 6.034 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.208152770996094 Min validation loss: 6.208152770996094
# Time for epoch: 305seconds
# Est remaining time: 1 day, 9:38:05 or 121085 seconds
# ----------------------------------------
# Epoch[104/500] Training Loss: 6.206 Reconstruction Loss: 6.033 KL Loss: 0.172
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.209290504455566 Min validation loss: 6.208152770996094
# Time for epoch: 306seconds
# Est remaining time: 1 day, 9:39:36 or 121176 seconds
# ----------------------------------------
# Epoch[105/500] Training Loss: 6.208 Reconstruction Loss: 6.035 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.20891809463501 Min validation loss: 6.208152770996094
# Time for epoch: 305seconds
# Est remaining time: 1 day, 9:27:55 or 120475 seconds
# ----------------------------------------
# Testing the model at step 42000
# Epoch[106/500] Training Loss: 6.206 Reconstruction Loss: 6.033 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Epoch 00106: reducing learning rate of group 0 to 3.7500e-05.
# Patience: 3 Validation Loss: 6.210308074951172 Min validation loss: 6.208152770996094
# Time for epoch: 303seconds
# Est remaining time: 1 day, 9:09:42 or 119382 seconds
# ----------------------------------------
# Epoch[107/500] Training Loss: 6.208 Reconstruction Loss: 6.035 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# saving ./Trained_model/model/convallaria_best_vae.net
# Patience: 0 Validation Loss: 6.206910133361816 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 9:04:39 or 119079 seconds
# ----------------------------------------
# Testing the model at step 43000
# Epoch[108/500] Training Loss: 6.208 Reconstruction Loss: 6.035 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 1 Validation Loss: 6.2098708152771 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 9:06:08 or 119168 seconds
# ----------------------------------------
# Epoch[109/500] Training Loss: 6.208 Reconstruction Loss: 6.035 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 2 Validation Loss: 6.207918167114258 Min validation loss: 6.206910133361816
# Time for epoch: 306seconds
# Est remaining time: 1 day, 9:14:06 or 119646 seconds
# ----------------------------------------
# Epoch[110/500] Training Loss: 6.206 Reconstruction Loss: 6.033 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 3 Validation Loss: 6.210853576660156 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 9:02:30 or 118950 seconds
# ----------------------------------------
# Testing the model at step 44000
# Epoch[111/500] Training Loss: 6.203 Reconstruction Loss: 6.030 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 4 Validation Loss: 6.209867477416992 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 8:50:56 or 118256 seconds
# ----------------------------------------
# Epoch[112/500] Training Loss: 6.207 Reconstruction Loss: 6.034 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 5 Validation Loss: 6.210226058959961 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 8:39:24 or 117564 seconds
# ----------------------------------------
# Testing the model at step 45000
# Epoch[113/500] Training Loss: 6.207 Reconstruction Loss: 6.033 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 6 Validation Loss: 6.209216117858887 Min validation loss: 6.206910133361816
# Time for epoch: 306seconds
# Est remaining time: 1 day, 8:53:42 or 118422 seconds
# ----------------------------------------
# Epoch[114/500] Training Loss: 6.206 Reconstruction Loss: 6.032 KL Loss: 0.173
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 7 Validation Loss: 6.2086286544799805 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 8:42:10 or 117730 seconds
# ----------------------------------------
# Epoch[115/500] Training Loss: 6.206 Reconstruction Loss: 6.033 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 8 Validation Loss: 6.209066390991211 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 8:24:15 or 116655 seconds
# ----------------------------------------
# Testing the model at step 46000
# Epoch[116/500] Training Loss: 6.206 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 9 Validation Loss: 6.207601547241211 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 8:25:36 or 116736 seconds
# ----------------------------------------
# Epoch[117/500] Training Loss: 6.205 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 10 Validation Loss: 6.20737361907959 Min validation loss: 6.206910133361816
# Time for epoch: 306seconds
# Est remaining time: 1 day, 8:33:18 or 117198 seconds
# ----------------------------------------
# Testing the model at step 47000
# Epoch[118/500] Training Loss: 6.207 Reconstruction Loss: 6.034 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Epoch 00118: reducing learning rate of group 0 to 1.8750e-05.
# Patience: 11 Validation Loss: 6.208838939666748 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 8:21:50 or 116510 seconds
# ----------------------------------------
# Epoch[119/500] Training Loss: 6.204 Reconstruction Loss: 6.031 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 12 Validation Loss: 6.212000846862793 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 8:04:03 or 115443 seconds
# ----------------------------------------
# Epoch[120/500] Training Loss: 6.206 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 13 Validation Loss: 6.209519386291504 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 7:59:00 or 115140 seconds
# ----------------------------------------
# Testing the model at step 48000
# Epoch[121/500] Training Loss: 6.205 Reconstruction Loss: 6.031 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 14 Validation Loss: 6.208968162536621 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 8:00:16 or 115216 seconds
# ----------------------------------------
# Epoch[122/500] Training Loss: 6.206 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 15 Validation Loss: 6.208137512207031 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 8:01:30 or 115290 seconds
# ----------------------------------------
# Testing the model at step 49000
# Epoch[123/500] Training Loss: 6.206 Reconstruction Loss: 6.031 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 16 Validation Loss: 6.209129810333252 Min validation loss: 6.206910133361816
# Time for epoch: 306seconds
# Est remaining time: 1 day, 8:02:42 or 115362 seconds
# ----------------------------------------
# Epoch[124/500] Training Loss: 6.207 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 17 Validation Loss: 6.210564136505127 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 7:45:04 or 114304 seconds
# ----------------------------------------
# Epoch[125/500] Training Loss: 6.207 Reconstruction Loss: 6.033 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 18 Validation Loss: 6.208922386169434 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 7:33:45 or 113625 seconds
# ----------------------------------------
# Testing the model at step 50000
# Epoch[126/500] Training Loss: 6.205 Reconstruction Loss: 6.031 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 19 Validation Loss: 6.208315849304199 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 7:41:10 or 114070 seconds
# ----------------------------------------
# Epoch[127/500] Training Loss: 6.206 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 20 Validation Loss: 6.210283279418945 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 7:36:05 or 113765 seconds
# ----------------------------------------
# Testing the model at step 51000
# Epoch[128/500] Training Loss: 6.203 Reconstruction Loss: 6.029 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 21 Validation Loss: 6.20820951461792 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 7:24:48 or 113088 seconds
# ----------------------------------------
# Epoch[129/500] Training Loss: 6.210 Reconstruction Loss: 6.035 KL Loss: 0.175
# saving ./Trained_model/model/convallaria_last_vae.net
# Epoch 00129: reducing learning rate of group 0 to 9.3750e-06.
# Patience: 22 Validation Loss: 6.209503173828125 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 7:13:33 or 112413 seconds
# ----------------------------------------
# Epoch[130/500] Training Loss: 6.206 Reconstruction Loss: 6.032 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 23 Validation Loss: 6.209263801574707 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 7:20:50 or 112850 seconds
# ----------------------------------------
# Testing the model at step 52000
# Epoch[131/500] Training Loss: 6.207 Reconstruction Loss: 6.032 KL Loss: 0.175
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 24 Validation Loss: 6.208451271057129 Min validation loss: 6.206910133361816
# Time for epoch: 306seconds
# Est remaining time: 1 day, 7:21:54 or 112914 seconds
# ----------------------------------------
# Epoch[132/500] Training Loss: 6.207 Reconstruction Loss: 6.033 KL Loss: 0.175
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 25 Validation Loss: 6.207921981811523 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 7:10:40 or 112240 seconds
# ----------------------------------------
# Testing the model at step 53000
# Epoch[133/500] Training Loss: 6.204 Reconstruction Loss: 6.029 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 26 Validation Loss: 6.207865238189697 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 6:53:21 or 111201 seconds
# ----------------------------------------
# Epoch[134/500] Training Loss: 6.207 Reconstruction Loss: 6.032 KL Loss: 0.175
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 27 Validation Loss: 6.209300994873047 Min validation loss: 6.206910133361816
# Time for epoch: 303seconds
# Est remaining time: 1 day, 6:48:18 or 110898 seconds
# ----------------------------------------
# Epoch[135/500] Training Loss: 6.204 Reconstruction Loss: 6.029 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 28 Validation Loss: 6.209766387939453 Min validation loss: 6.206910133361816
# Time for epoch: 305seconds
# Est remaining time: 1 day, 6:55:25 or 111325 seconds
# ----------------------------------------
# Testing the model at step 54000
# Epoch[136/500] Training Loss: 6.205 Reconstruction Loss: 6.030 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 29 Validation Loss: 6.206939697265625 Min validation loss: 6.206910133361816
# Time for epoch: 306seconds
# Est remaining time: 1 day, 6:56:24 or 111384 seconds
# ----------------------------------------
# Epoch[137/500] Training Loss: 6.203 Reconstruction Loss: 6.029 KL Loss: 0.174
# saving ./Trained_model/model/convallaria_last_vae.net
# Patience: 30 Validation Loss: 6.208406448364258 Min validation loss: 6.206910133361816
# Time for epoch: 304seconds
# Est remaining time: 1 day, 6:39:12 or 110352 seconds
# ----------------------------------------

# %% [markdown]
# # Plotting losses

# %%
trainHist=np.load(directory_path+"model/train_loss.npy")
reconHist=np.load(directory_path+"model/train_reco_loss.npy")
klHist=np.load(directory_path+"model/train_kl_loss.npy")
valHist=np.load(directory_path+"model/val_loss.npy")

# %%
plt.figure(figsize=(18, 3))
plt.subplot(1,3,1)
plt.plot(trainHist,label='training')
plt.plot(valHist,label='validation')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()

plt.subplot(1,3,2)
plt.plot(reconHist,label='training')
plt.xlabel("epochs")
plt.ylabel("reconstruction loss")
plt.legend()

plt.subplot(1,3,3)
plt.plot(klHist,label='training')
plt.xlabel("epochs")
plt.ylabel("KL loss")
plt.legend()
plt.show()
